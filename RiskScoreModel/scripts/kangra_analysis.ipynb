# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
risk_score = pd.read_csv(r'D:\CivicDataLab_IDS-DRR\IDS-DRR_Github\HP\flood-data-ecosystem-Himachal-Pradesh\RiskScoreModel\data\risk_score_final_district.csv')

# %%
kangra = risk_score.loc[(risk_score['district'] == 'KANGRA') & (risk_score['timeperiod'] == "2024_08")]
kangra
# Out:
#          object-id   tehsil-area district timeperiod  \
# 4480  02-024-02122  3.085761e+08   KANGRA    2024_08
# 4482  02-024-02123  1.679257e+08   KANGRA    2024_08
# 4483  02-024-02113  5.388599e+08   KANGRA    2024_08
# 4484  02-024-02130  2.443730e+08   KANGRA    2024_08
# 4485  02-024-02121  1.221134e+08   KANGRA    2024_08
# 4486  02-024-02117  7.216611e+07   KANGRA    2024_08
# 4487  02-024-02111  1.340407e+08   KANGRA    2024_08
# 4490  02-024-02114  3.373645e+08   KANGRA    2024_08
# 4493  02-024-02118  3.274405e+08   KANGRA    2024_08
# 4500  02-024-02127  5.398900e+08   KANGRA    2024_08
# 4507  02-024-02110  2.928289e+08   KANGRA    2024_08
# 4511  02-024-02131  5.772050e+07   KANGRA    2024_08
# 4512  02-024-02126  1.076842e+08   KANGRA    2024_08
# 4522  02-024-02115  8.120405e+07   KANGRA    2024_08
# 4523  02-024-02129  1.164017e+08   KANGRA    2024_08
# 4524  02-024-02124  1.912405e+08   KANGRA    2024_08
# 4525  02-024-02120  1.110761e+08   KANGRA    2024_08
# ...

# %%
district_rainfall = kangra.groupby('district')['sum-runoff'].sum().reset_index()
district_rainfall
# Out:
#   district  sum-runoff
# 0   KANGRA  39321.2563
